# %%
#Creating dictionary
student ={
    "name": "Tony",
    "age" : 22,
    "course" : "dsml"
}

print(f"studet data = {student}")
print(f"student name = {student['name']}")
print(f"student age = {student['age']}")
print(f"student course = {student['course']}")
# Out:
# studet data = {'name': 'Tony', 'age': 22, 'course': 'dsml'}
# student name = Tony
# student age = 22
# student course = dsml

# %%
#creating dictionary using dict()
dict_data =  dict({
    "name" : "richard",
    "home" : "usa",
    "phone" : 65445554,
    "courses" : ["dsml", "python", "java"] #list inside dictionary
})
print(f"dict_data = {dict_data}")
print(f"dict_data name = {dict_data['name']}")
print(f"dict_data home = {dict_data['home']}")
print(f"dict_data phone = {dict_data['phone']}")
print(f"dict_data courses = {dict_data['courses']}")
# Out:
# dict_data = {'name': 'richard', 'home': 'usa', 'phone': 65445554, 'courses': ['dsml', 'python', 'java']}
# dict_data name = richard
# dict_data home = usa
# dict_data phone = 65445554
# dict_data courses = ['dsml', 'python', 'java']

# %%
#another way
person = dict([("name", "roman"), ("Address", "London")])
print(dict)
print(f"person name = {person['name']}")
print(f"person address = {person['Address']}")
# Out:
# <class 'dict'>
# person name = roman
# person address = London

# %%
#modifying data
student["age"] = 30
print(f"student data  = {student}")
# Out:
# student data  = {'name': 'Tony', 'age': 30, 'course': 'dsml'}

# %% [markdown]
# ## Different dictionary methods

# %%
# keys()
student.keys()
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
#values()
student.values()
# Out:
# dict_values(['Tony', 30, 'dsml'])

# %%
#items()
student.items()
# Out:
# dict_items([('name', 'Tony'), ('age', 30), ('course', 'dsml')])

# %%
#pop
student.pop("name")
# Out:
# 'Tony'

# %%
#pop with message | Here "Not found" is a message
student.pop("name", "Not found")
# Out:
# 'Not found'

# %%
dict_data =  dict({
    "name" : "richard",
    "home" : "usa",
    "phone" : 65445554,
    "courses" : ["dsml", "python", "java"] #list inside dictionary
})

# %%
#popitem()
dict_data.popitem()
# Out:
# ('courses', ['dsml', 'python', 'java'])

# %%
#del
# print(del dict_data['name']) | won't run as it doesn't return the value
del dict_data['name']

# %%
dict_data
# Out:
# {'home': 'usa', 'phone': 65445554}

# %%
#dictionary concationation
dict1 ={
    "name":"stard",
    "age" :22
}
dict2 ={
    "name":"tony", # If provides same key than later value provided will overwrite
    "city":"btm",
    "state":"karnataka"
}
dict1.update(dict2)
print(f"dict1 = {dict1}")
print(f"dict2 = {dict2}")
#print(f"dict1 + dict2 = {dict1 + dict2}") # won't work
print(f"dict1.update(dict2) = {dict1}")
# Out:
# dict1 = {'name': 'tony', 'age': 22, 'city': 'btm', 'state': 'karnataka'}
# dict2 = {'name': 'tony', 'city': 'btm', 'state': 'karnataka'}
# dict1.update(dict2) = {'name': 'tony', 'age': 22, 'city': 'btm', 'state': 'karnataka'}

# %%
#using #kwargs to unpack
dict3 ={
    "gender" : "male",
    "marks" : 45
}

st_data = {**dict1,**dict2, **dict3}
print(f"st_data = {st_data}")
#
# Out:
# st_data = {'name': 'tony', 'age': 22, 'city': 'btm', 'state': 'karnataka', 'gender': 'male', 'marks': 45}

# %%
#sort
result = sorted(st_data)
print(f"result = {result}")
# Out:
# result = ['age', 'city', 'gender', 'marks', 'name', 'state']

# %%
#merge dictionary
dict1 | dict2 | dict3
# Out:
# {'name': 'tony',
#  'age': 22,
#  'city': 'btm',
#  'state': 'karnataka',
#  'gender': 'male',
#  'marks': 45}

# %%
#len()
len(dict1)
# Out:
# 4

# %%
# set default
dict_data.setdefault("name", "hello")
# Out:
# 'hello'

# %%
dict_data =  dict({
    "name" : "richard",
    "home" : "usa",
    "phone" : 65445554,
    "courses" : ["dsml", "python", "java"] #list inside dictionary
})

# %%
#checks key in dictionary
"salary" in dict_data
# Out:
# False

# %%
"home" in dict_data
# Out:
# True

# %%
#max and min values in dict only possible in numerical values
dict_={
    "a":1,
    "b":30
}
print(f"key holding max value = {max(dict_)}")
print(f"Key holding min value = {min(dict_)}")
print(f"max value = {max(dict_.values())}")
print(f"min value = {min(dict_.values())}")
# Out:
# key holding max value = b
# Key holding min value = a
# max value = 30
# min value = 1

# %%
#clear method
dict_.clear()

# %%
dict_
# Out:
# {}
