# %%
#list
#tuples
#set
#dictionary

# %%
my_list = [10,20, 30, 40, 50,60]

# %%
#slicing

# %%
#Q1 [30, 40, 50]
my_list[2:5]
# Out:
# [30, 40, 50]

# %%
#q2 [10, 20, 30]
my_list[0:3]
# Out:
# [10, 20, 30]

# %%
#q3[10, 30, 50]
my_list[0:6:2]
# Out:
# [10, 30, 50]

# %%
#q4 [40, 50, 60]
my_list[3:6]
# Out:
# [40, 50, 60]

# %%
#q5[60, 50, 40, 30, 20, 10]
my_list[::-1]
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
#q6[10, 20, 30, 40, 50, 60]
my_list[:]
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
#append
my_list.append(100)

# %%
my_list
# Out:
# [10, 20, 30, 40, 50, 60, 100]

# %%
#extend
list = ["name","age","gender"]

# %%
my_list.extend(list)

# %%
my_list
# Out:
# [10, 20, 30, 40, 50, 60, 100, 'name', 'age', 'gender']

# %%
#insert
my_list.insert(2,300)

# %%
my_list
# Out:
# [10, 20, 300, 30, 40, 50, 60, 100, 'name', 'age', 'gender']

# %%
#index
my_list.index("name")
# Out:
# 8

# %%
my_list.remove(300) #remove

# %%
my_list
# Out:
# [10, 20, 30, 40, 50, 60, 100, 'name', 'age', 'gender']

# %%
#pop
my_list.pop(3)
# Out:
# 40

# %%
my_list.clear()

# %%
my_list
# Out:
# []

# %%
data = [10,20,30,40,50,30,20,30]
data.count(20)
# Out:
# 2

# %%
data.sort() #sosrt in ascending order

# %%
data
# Out:
# [10, 20, 20, 30, 30, 30, 40, 50]

# %%
data.reverse() #reverse the list

# %%
data
# Out:
# [50, 40, 30, 30, 30, 20, 20, 10]

# %%
data1 = data.copy() #copies the data values into data1

# %%
data
# Out:
# [50, 40, 30, 30, 30, 20, 20, 10]

# %% [markdown]
# Shallow copy vs deep copy

# %%
lst = [[1,2,3,4],[23,3,4,6,7]]
lst1 = lst

# %%
lst2 = lst.copy()

# %%
lst[1][1] =59 #soft copy
print(lst)
print(lst2)
# Out:
# [[1, 2, 3, 4], [23, 59, 4, 6, 7]]
# [[1, 2, 3, 4], [23, 59, 4, 6, 7]]

# %%
#deep copy
import copy

# %%
datas = [[1,2,3,4],[23,3,4,6,7]]
datas1 = copy.deepcopy(datas)

# %%
datas[1][1] =100

# %%
print(datas)
print(datas1)
# Out:
# [[1, 2, 3, 4], [23, 100, 4, 6, 7]]
# [[1, 2, 3, 4], [23, 3, 4, 6, 7]]

# %%
# append() acts as the push operation by adding an element to the end of the list, and pop() removes the last element by default.
#Together, they follow the stack (LIFO – Last In, First Out) principle.

# %%
dummy = []
a = input("enter your name: ")
# Out:
# enter your name: avhi

# %%
dummy.append(a) # In Python list don't have a push method so we use append to push

# %%
b = int(input("enter your age:"))
# Out:
# enter your age:22

# %%
dummy.append(b)

# %%
c = input("enter your stream: ")
# Out:
# enter your stream: dsml

# %%
dummy.append(c)

# %%
dummy
# Out:
# ['avhi', 22, 'dsml']

# %%
dummy.pop()
# Out:
# 'dsml'

# %%
dummy.pop()
# Out:
# 22

# %%
dummy.pop()
# Out:
# 'avhi'

# %%
dummy
# Out:
# []

# %%
#enqueue and dequeue
from collections import deque

queue = deque()

# Enqueue
queue.append("Gaurav")
queue.append("Rahul")
queue.append("Sita")

queue
# Out:
# deque(['Gaurav', 'Rahul', 'Sita'])

# %%
#deque
queue.popleft()
# Out:
# 'Gaurav'

# %%
queue.popleft()
# Out:
# 'Rahul'

# %%
queue.popleft()
# Out:
# 'Sita'

# %%
queue
# Out:
# deque([])
